# %%
import requests
import json
import os
import pandas
from IPython.display import display
import pandasql

# %%
api_key = os.environ.get("FRESH_DESK_API_KEY")
domain = "embraceio"
url = f"https://{domain}.freshdesk.com/api/v2/tickets"
response = requests.get(url=url, auth=(api_key, "x"))

# %%
if response.status_code == 200:
    print("Requests processed successfully")
    data = json.loads(response.content)
    # print(data)
else:
    print("Failed to read tickets")
    response = json.loads(response.content)
    print(response["errors"])
# Out:
# Requests processed successfully

# %% [markdown]
# # Pandasql: Allows you to use sql to query pandas dataframes: Doc ([sqldf for pandas](https://pythonrepo.com/repo/yhat-pandasql-python-data-containers))

# %%
pysqldf = lambda q: pandasql.sqldf(q, globals())

# %%
tickets_raw_df = pandas.DataFrame.from_dict(data)
tickets_raw_df

# %%
tickets_df = tickets_raw_df[["id", "custom_fields", "created_at", "updated_at"]]
tickets_df = tickets_df.applymap(str)

# %%
# Get custom fields values into seperate rows
custom_fields = tickets_raw_df["custom_fields"].tolist()
custom_fields_df = pandas.DataFrame(custom_fields, columns=["cf_responsible_engineer", "cf_account_type", "cf_app_id", "cf_main_cs_contact"])
custom_fields_df["id"] = tickets_raw_df["id"]
custom_fields_df = custom_fields_df.applymap(str)

# %%
# Combine custom fields data (seperate rows) with tickets data
q = """
    SELECT 
          tickets_df.id
        , tickets_df.custom_fields
        , custom_fields_df.cf_responsible_engineer
        , custom_fields_df.cf_main_cs_contact
        , custom_fields_df.cf_account_type
        , custom_fields_df.cf_app_id
        , tickets_df.created_at
        , tickets_df.updated_at
    FROM tickets_df
    INNER JOIN custom_fields_df
        ON custom_fields_df.id = tickets_df.id
    ;
"""

combined_df = pysqldf(q)
display(combined_df)

# %% [markdown]
# # FreshDesk Groups

# %%
api_key = os.environ.get("FRESH_DESK_API_KEY")
domain = "embraceio"
url = f"https://{domain}.freshdesk.com/api/v2/groups?per_page=100"
response = requests.get(url=url, auth=(api_key, "x"))

# %%
if response.status_code == 200:
    print("Requests processed successfully")
    data = json.loads(response.content)
    # print(data)
else:
    print("Failed to read tickets")
    response = json.loads(response.content)
    print(response["errors"])
# Out:
# Requests processed successfully

# %%
groups_raw_df = pandas.DataFrame.from_dict(data)
groups_raw_df
# Out:
#             id                       name    description escalate_to  \
# 0  66000168193           Customer Success           None        None
# 1  66000168199           Engineering - BE           None        None
# 2  66000429874           Engineering - FE  Frontend Team        None
# 3  66000433581          Engineering - SDK           None        None
# 4  66000168111                    Product           None        None
# 5  66000427634             Sales Engineer           None        None
# 6  66000435712  Support - Customer Sucess           None        None
#
#   unassigned_for business_hour_id           group_type            created_at  \
# 0           None             None  support_agent_group  2020-09-18T19:26:05Z
# 1           None             None  support_agent_group  2020-09-18T19:26:29Z
# 2           None             None  support_agent_group  2021-04-15T18:16:28Z
# 3           None             None  support_agent_group  2021-07-23T23:25:36Z
# 4           None             None  support_agent_group  2020-09-18T18:46:19Z
# 5           None             None  support_agent_group  2021-02-23T16:42:05Z
# 6           None             None  support_agent_group  2021-10-15T16:59:37Z
#
#              updated_at  auto_ticket_assign
# 0  2021-10-06T16:13:14Z                   0
# 1  2021-08-02T15:50:26Z                   0
# 2  2021-04-15T18:16:28Z                   0
# 3  2021-10-06T16:20:02Z                   0
# 4  2020-09-30T15:10:12Z                   0
# 5  2021-02-23T16:42:05Z                   0
# 6  2021-10-19T11:02:15Z                   0

# %% [markdown]
# # FD Status Mapping
#
# - [How to get all the options for ticket status field through API?](https://community.developers.freshworks.com/t/how-to-get-all-the-options-for-ticket-status-field-through-api/1338)

# %%
api_key = os.environ.get("FRESH_DESK_API_KEY")
domain = "embraceio"
url = f'https://{domain}.freshdesk.com/api/v2/admin/ticket_fields/66000277594'
response = requests.get(url=url, auth=(api_key, "x"))

# %%
if response.status_code == 200:
    print("Requests processed successfully")
    data = json.loads(response.content)
    # print(data)
else:
    print("Failed to read tickets")
    response = json.loads(response.content)
    print(response["errors"])
# Out:
# Requests processed successfully

# %%
data
# Out:
# {'id': 66000277594,
#  'name': 'status',
#  'label': 'Status',
#  'label_for_customers': 'Status',
#  'position': 9,
#  'type': 'default_status',
#  'default': True,
#  'customers_can_edit': False,
#  'required_for_closure': False,
#  'required_for_agents': True,
#  'required_for_customers': False,
#  'displayed_to_customers': True,
#  'created_at': '2020-09-18T18:46:18Z',
#  'updated_at': '2022-03-23T19:16:34Z',
#  'archived': False,
#  'choices': [{'id': 2,
#    'label': 'Open',
#    'label_for_customers': 'Being Processed',
#    'value': 'Open',
#    'stop_sla_timer': False,
#    'default': True,
#    'position': 1,
#    'deleted': False},
#   {'id': 8,
#    'label': 'Backlog',
#    'label_for_customers': 'This ticket has been Closed',
#    'value': 'Backlog',
#    'stop_sla_timer': True,
#    'default': False,
#    'position': 2,
#    'deleted': False,
#    'group_ids': [66000168111,
#     66000168193,
#     66000168199,
#     66000429874,
#     66000433581,
#     66000435712,
#     66000438079,
#     66000427634,
#     66000439756]},
#   {'id': 9,
#    'label': 'Triage',
#    'label_for_customers': 'Being Processed',
#    'value': 'Triage',
#    'stop_sla_timer': False,
#    'default': False,
#    'position': 3,
#    'deleted': False,
#    'group_ids': [66000435712]},
#   {'id': 11,
#    'label': 'Assigned to Product Team',
#    'label_for_customers': 'Assigned to Product Team',
#    'value': 'Assigned to Product Team',
#    'stop_sla_timer': True,
#    'default': False,
#    'position': 4,
#    'deleted': False,
#    'group_ids': [66000168111]},
#   {'id': 10,
#    'label': 'Assigned to Eng Team - Triage',
#    'label_for_customers': 'Being Processed',
#    'value': 'Assigned to Eng Team - Triage',
#    'stop_sla_timer': False,
#    'default': False,
#    'position': 5,
#    'deleted': False,
#    'group_ids': [66000168199,
#     66000429874,
#     66000433581,
#     66000438079,
#     66000439756]},
#   {'id': 7,
#    'label': 'In progress',
#    'label_for_customers': 'In progress',
#    'value': 'In progress',
#    'stop_sla_timer': False,
#    'default': False,
#    'position': 6,
#    'deleted': False,
#    'group_ids': [66000168111,
#     66000168193,
#     66000168199,
#     66000427634,
#     66000429874,
#     66000433581,
#     66000435712,
#     66000438079,
#     66000439756]},
#   {'id': 6,
#    'label': 'Waiting on Customer',
#    'label_for_customers': 'Awaiting your Reply',
#    'value': 'Waiting on Customer',
#    'stop_sla_timer': True,
#    'default': False,
#    'position': 8,
#    'deleted': False,
#    'group_ids': [66000168193, 66000427634, 66000435712]},
#   {'id': 12,
#    'label': 'Pending - CS',
#    'label_for_customers': 'In progress',
#    'value': 'Pending - CS',
#    'stop_sla_timer': False,
#    'default': False,
#    'position': 9,
#    'deleted': False,
#    'group_ids': [66000168111,
#     66000168193,
#     66000168199,
#     66000427634,
#     66000429874,
#     66000433581,
#     66000435712,
#     66000438079,
#     66000439756]},
#   {'id': 3,
#    'label': 'Pending',
#    'label_for_customers': 'In progress',
#    'value': 'Pending',
#    'stop_sla_timer': False,
#    'default': True,
#    'position': 10,
#    'deleted': False},
#   {'id': 4,
#    'label': 'Resolved',
#    'label_for_customers': 'This ticket has been Resolved',
#    'value': 'Resolved',
#    'stop_sla_timer': True,
#    'default': True,
#    'position': 11,
#    'deleted': False},
#   {'id': 5,
#    'label': 'Closed',
#    'label_for_customers': 'This ticket has been Closed',
#    'value': 'Closed',
#    'stop_sla_timer': True,
#    'default': True,
#    'position': 12,
#    'deleted': False}]}

# %%
status_raw_df = pandas.DataFrame.from_dict(data)
status_choices_df = pandas.DataFrame(status_raw_df["choices"].tolist(), columns=['id', 'value'])
status_choices_df
# Out:
#     id                          value
# 0    2                           Open
# 1    8                        Backlog
# 2    9                         Triage
# 3   11       Assigned to Product Team
# 4   10  Assigned to Eng Team - Triage
# 5    7                    In progress
# 6    6            Waiting on Customer
# 7   12                   Pending - CS
# 8    3                        Pending
# 9    4                       Resolved
# 10   5                         Closed

# %% [markdown]
# # FD Priority Mapping

# %%
api_key = os.environ.get('FRESH_DESK_API_KEY')
domain = 'embraceio'
url = f'https://{domain}.freshdesk.com/api/v2/admin/ticket_fields/66000277595'
response = requests.get(url=url, auth=(api_key, "x"))

if response.status_code == 200:
    print("Requests processed successfully")
    data = json.loads(response.content)
    print(data)
else:
    print("Failed to read tickets")
    response = json.loads(response.content)
    print(response["errors"])
# Out:
# Requests processed successfully
# {'id': 66000277595, 'name': 'priority', 'label': 'Priority', 'label_for_customers': 'Priority', 'position': 10, 'type': 'default_priority', 'default': True, 'customers_can_edit': True, 'required_for_closure': False, 'required_for_agents': True, 'required_for_customers': False, 'displayed_to_customers': True, 'created_at': '2020-09-18T18:46:18Z', 'updated_at': '2021-03-09T20:58:22Z', 'archived': False, 'choices': [{'label': 'Low', 'value': 1}, {'label': 'Medium', 'value': 2}, {'label': 'High', 'value': 3}, {'label': 'Urgent', 'value': 4}]}

# %%
priority_raw_df = pandas.DataFrame.from_dict(data)
priority_choices_df = pandas.DataFrame(priority_raw_df['choices'].tolist(), columns=['label', 'value'])
priority_choices_df
# Out:
#     label  value
# 0     Low      1
# 1  Medium      2
# 2    High      3
# 3  Urgent      4

# %% [markdown]
# # Eng FD On Call Tickets

# %%
api_key = os.environ.get("FRESH_DESK_API_KEY")
domain = "embraceio"
url = f'https://{domain}.freshdesk.com/api/v2/search/tickets?query="tag:"PRIORITY-ENG-FD-ONCALL" " '
response = requests.get(url=url, auth=(api_key, "x"))

# %%
if response.status_code == 200:
    print("Requests processed successfully")
    data = json.loads(response.content)
    # print(data)
else:
    print("Failed to read tickets")
    response = json.loads(response.content)
    print(response["errors"])
# Out:
# Requests processed successfully

# %%
data
# Out:
# [{'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': False,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168193,
#   'priority': 2,
#   'requester_id': 66017283504,
#   'responder_id': 66020186877,
#   'source': 3,
#   'company_id': 66000360237,
#   'status': 2,
#   'subject': 'Tala -Android - Snoozed a crash but still got an alert',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1508,
#   'type': 'Feature Request',
#   'due_by': '2021-11-25T15:08:34Z',
#   'fr_due_by': '2021-11-05T23:08:34Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': '/QsT3b',
#    'cf_main_cs_contact': 'Harry Schaffer',
#    'cf_in_notion_priority_ticket_db': True},
#   'created_at': '2021-11-05T15:08:34Z',
#   'updated_at': '2021-11-06T02:53:08Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': False,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168193,
#   'priority': 2,
#   'requester_id': 66017753344,
#   'responder_id': 66018795934,
#   'source': 100,
#   'company_id': 66000425941,
#   'status': 5,
#   'subject': 'Cocoapods Issue',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1506,
#   'type': 'Question',
#   'due_by': '2021-11-24T20:14:09Z',
#   'fr_due_by': '2021-11-05T04:14:09Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': 'edkud',
#    'cf_main_cs_contact': 'Brian Schell',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-04T20:14:09Z',
#   'updated_at': '2021-11-04T20:32:21Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': ['yuri.visser@2k.com', 'support@embrace.io'],
#   'fwd_emails': [],
#   'reply_cc_emails': ['yuri.visser@2k.com', 'support@embrace.io'],
#   'ticket_cc_emails': [],
#   'fr_escalated': False,
#   'spam': False,
#   'email_config_id': 66000070707,
#   'group_id': 66000168193,
#   'priority': 1,
#   'requester_id': 66021715657,
#   'responder_id': 66004145045,
#   'source': 1,
#   'company_id': None,
#   'status': 2,
#   'subject': 'Admin changes',
#   'association_type': None,
#   'support_email': 'embraceiosupport@embraceio.freshdesk.com',
#   'to_emails': ['"support@embrace.io" <support@embrace.io>'],
#   'product_id': None,
#   'id': 1505,
#   'type': None,
#   'due_by': '2021-12-04T17:58:31Z',
#   'fr_due_by': '2021-11-05T17:58:31Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': None,
#    'cf_app_id': None,
#    'cf_main_cs_contact': None,
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-04T17:58:31Z',
#   'updated_at': '2021-11-04T18:43:57Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000435712,
#   'priority': 2,
#   'requester_id': 66020491127,
#   'responder_id': 66020491127,
#   'source': 100,
#   'company_id': None,
#   'status': 10,
#   'subject': 'IOS - Breadcrumbs Default Limit',
#   'association_type': 4,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1504,
#   'type': 'Bug',
#   'due_by': '2021-11-24T15:06:50Z',
#   'fr_due_by': '2021-11-04T23:06:50Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Other',
#    'cf_app_id': None,
#    'cf_main_cs_contact': None,
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-04T11:37:43Z',
#   'updated_at': '2021-11-04T23:08:51Z',
#   'associated_tickets_count': None,
#   'tags': ['PRIORITY-ENG-IOS'],
#   'internal_agent_id': None,
#   'internal_group_id': 66000433581,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000435712,
#   'priority': 2,
#   'requester_id': 66020491127,
#   'responder_id': 66020491127,
#   'source': 100,
#   'company_id': None,
#   'status': 10,
#   'subject': 'Android - Breadcrumbs Default Limit',
#   'association_type': 4,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1503,
#   'type': 'Bug',
#   'due_by': '2021-11-24T14:59:04Z',
#   'fr_due_by': '2021-11-04T22:59:04Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Other',
#    'cf_app_id': None,
#    'cf_main_cs_contact': None,
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-04T11:32:05Z',
#   'updated_at': '2021-11-04T23:08:51Z',
#   'associated_tickets_count': None,
#   'tags': ['PRIORITY-ENG-ANDROID'],
#   'internal_agent_id': None,
#   'internal_group_id': 66000433581,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000435712,
#   'priority': 3,
#   'requester_id': 66020491127,
#   'responder_id': 66020491127,
#   'source': 100,
#   'company_id': None,
#   'status': 7,
#   'subject': 'Android & IOS - Breadcrumbs Default Limit',
#   'association_type': 3,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1502,
#   'type': 'Bug',
#   'due_by': '2021-11-14T11:21:47Z',
#   'fr_due_by': '2021-11-04T15:21:49Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Other',
#    'cf_app_id': None,
#    'cf_main_cs_contact': None,
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-04T11:21:49Z',
#   'updated_at': '2021-11-04T19:55:14Z',
#   'associated_tickets_count': 3,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168199,
#   'priority': 3,
#   'requester_id': 66004132337,
#   'responder_id': 66014842864,
#   'source': 3,
#   'company_id': None,
#   'status': 5,
#   'subject': 'Public Paper docs',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1501,
#   'type': None,
#   'due_by': '2021-11-13T19:11:49Z',
#   'fr_due_by': '2021-11-03T23:11:49Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Other',
#    'cf_app_id': None,
#    'cf_main_cs_contact': 'Christine Hermawan',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-03T19:11:49Z',
#   'updated_at': '2021-11-04T18:55:12Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168193,
#   'priority': 1,
#   'requester_id': 66017315625,
#   'responder_id': 66018795934,
#   'source': 100,
#   'company_id': 66000478654,
#   'status': 2,
#   'subject': 'Various issues bundled under one crash',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1500,
#   'type': 'Question',
#   'due_by': '2021-12-03T16:18:07Z',
#   'fr_due_by': '2021-11-04T16:18:07Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': 'YFgVx',
#    'cf_main_cs_contact': 'Brian Schell',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-03T16:18:07Z',
#   'updated_at': '2021-11-05T21:33:54Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': False,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168193,
#   'priority': 1,
#   'requester_id': 66018673047,
#   'responder_id': 66020186877,
#   'source': 3,
#   'company_id': 66000391162,
#   'status': 5,
#   'subject': 'Ibotta - latest app version (iOS) not showing in dash automatically',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1499,
#   'type': 'Bug',
#   'due_by': '2021-12-03T15:25:35Z',
#   'fr_due_by': '2021-11-04T15:25:35Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': 'aw8oK',
#    'cf_main_cs_contact': 'Harry Schaffer',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-03T15:25:35Z',
#   'updated_at': '2021-11-04T19:26:49Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168193,
#   'priority': 2,
#   'requester_id': 66017315622,
#   'responder_id': 66018795934,
#   'source': 3,
#   'company_id': None,
#   'status': 2,
#   'subject': 'Embrace SDK Crashes',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1498,
#   'type': 'Integration',
#   'due_by': '2021-11-23T13:46:55Z',
#   'fr_due_by': '2021-11-03T21:46:55Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': 'YFgVx',
#    'cf_main_cs_contact': 'Brian Schell',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-03T13:46:55Z',
#   'updated_at': '2021-11-05T21:32:58Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': ['taylor.yang@starlight-sms.com'],
#   'fwd_emails': [],
#   'reply_cc_emails': ['taylor.yang@starlight-sms.com'],
#   'ticket_cc_emails': ['taylor.yang@starlight-sms.com'],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': 66000070707,
#   'group_id': 66000168193,
#   'priority': 1,
#   'requester_id': 66021688560,
#   'responder_id': 66018795934,
#   'source': 1,
#   'company_id': None,
#   'status': 10,
#   'subject': "Network calls aren't automatically tracked",
#   'association_type': None,
#   'support_email': 'embraceiosupport@embraceio.freshdesk.com',
#   'to_emails': ['support <support@embrace.io>'],
#   'product_id': None,
#   'id': 1496,
#   'type': 'Question',
#   'due_by': '2021-12-03T07:11:01Z',
#   'fr_due_by': '2021-11-04T07:11:01Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': None,
#    'cf_main_cs_contact': 'Brian Schell',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-03T07:11:01Z',
#   'updated_at': '2021-11-04T19:41:47Z',
#   'associated_tickets_count': None,
#   'tags': ['PRIORITY-ENG-ANDROID'],
#   'internal_agent_id': 66020732584,
#   'internal_group_id': 66000433581,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168193,
#   'priority': 2,
#   'requester_id': 66021679469,
#   'responder_id': 66018795934,
#   'source': 100,
#   'company_id': None,
#   'status': 3,
#   'subject': 'Swizzling Issue',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1495,
#   'type': 'Question',
#   'due_by': '2021-11-22T17:20:08Z',
#   'fr_due_by': '2021-11-03T01:20:09Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': 'ZWLeT',
#    'cf_main_cs_contact': 'Brian Schell',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-02T17:20:09Z',
#   'updated_at': '2021-11-04T01:10:35Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168193,
#   'priority': 1,
#   'requester_id': 66018048548,
#   'responder_id': 66020186877,
#   'source': 3,
#   'company_id': 66000439407,
#   'status': 7,
#   'subject': 'mayk.it - user sessions missing breadcrumbs that should be shown',
#   'association_type': 4,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1494,
#   'type': 'Bug',
#   'due_by': '2021-12-02T15:06:27Z',
#   'fr_due_by': '2021-11-03T15:06:27Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': '9uRQr',
#    'cf_main_cs_contact': 'Harry Schaffer',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-02T15:06:27Z',
#   'updated_at': '2021-11-04T11:21:50Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': 66020491127,
#   'internal_group_id': 66000435712,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168193,
#   'priority': 3,
#   'requester_id': 66021676522,
#   'responder_id': 66018795934,
#   'source': 100,
#   'company_id': None,
#   'status': 10,
#   'subject': 'Embrace Related Crashes (Top Crashes)',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1493,
#   'type': 'Question',
#   'due_by': '2021-11-12T14:48:19Z',
#   'fr_due_by': '2021-11-02T18:48:19Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': 'wJGQj',
#    'cf_main_cs_contact': 'Brian Schell',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-02T14:48:19Z',
#   'updated_at': '2021-11-02T18:55:55Z',
#   'associated_tickets_count': None,
#   'tags': ['PRIORITY-ENG-IOS'],
#   'internal_agent_id': 66018900669,
#   'internal_group_id': 66000433581,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': False,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168193,
#   'priority': 2,
#   'requester_id': 66017303414,
#   'responder_id': 66018795934,
#   'source': 100,
#   'company_id': 66000361269,
#   'status': 5,
#   'subject': 'dsym questions',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1492,
#   'type': 'Question',
#   'due_by': '2021-11-22T14:15:16Z',
#   'fr_due_by': '2021-11-02T22:15:16Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': 'ZWLeT',
#    'cf_main_cs_contact': 'Brian Schell',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-02T14:15:17Z',
#   'updated_at': '2021-11-02T20:41:18Z',
#   'associated_tickets_count': None,
#   'tags': ['PRIORITY-ENG-IOS'],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': False,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168193,
#   'priority': 3,
#   'requester_id': 66018549328,
#   'responder_id': 66016707941,
#   'source': 100,
#   'company_id': 66000360611,
#   'status': 6,
#   'subject': 'Moneylion - Phoebe chew not getting Daily Digests',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1489,
#   'type': 'Bug',
#   'due_by': '2021-11-11T15:52:53Z',
#   'fr_due_by': '2021-11-01T19:52:53Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': 'PeVHV and CKn3J',
#    'cf_main_cs_contact': 'Kathryn Hjalmarson',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-11-01T15:52:53Z',
#   'updated_at': '2021-11-04T02:51:36Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168193,
#   'priority': 2,
#   'requester_id': 66018621646,
#   'responder_id': 66018795934,
#   'source': 100,
#   'company_id': 66000391166,
#   'status': 10,
#   'subject': 'OKCupid Android Support w/ Connection Errors',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1486,
#   'type': 'Question',
#   'due_by': '2021-11-18T22:16:12Z',
#   'fr_due_by': '2021-10-30T06:16:12Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': '28r9d',
#    'cf_main_cs_contact': 'Brian Schell',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-10-29T22:16:13Z',
#   'updated_at': '2021-11-05T23:14:42Z',
#   'associated_tickets_count': None,
#   'tags': ['PRIORITY-ENG-ANDROID'],
#   'internal_agent_id': 66020732584,
#   'internal_group_id': 66000433581,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168199,
#   'priority': 3,
#   'requester_id': 66004132337,
#   'responder_id': 66006151299,
#   'source': 3,
#   'company_id': None,
#   'status': 7,
#   'subject': 'Deploy EOG Crash Report',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1485,
#   'type': None,
#   'due_by': '2021-11-07T23:02:47Z',
#   'fr_due_by': '2021-10-29T03:02:47Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': 'Many',
#    'cf_main_cs_contact': 'Harry Schaffer',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-10-28T23:02:47Z',
#   'updated_at': '2021-11-05T17:52:47Z',
#   'associated_tickets_count': None,
#   'tags': ['PRIORITY-ENG-DASH'],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000435712,
#   'priority': 2,
#   'requester_id': 66020491127,
#   'responder_id': 66020491127,
#   'source': 3,
#   'company_id': None,
#   'status': 5,
#   'subject': 'IOS Wrong SDK Version (App Release  is Same as SDK Version)',
#   'association_type': 3,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1484,
#   'type': None,
#   'due_by': '2021-11-17T20:41:17Z',
#   'fr_due_by': '2021-10-29T04:41:17Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Other',
#    'cf_app_id': None,
#    'cf_main_cs_contact': None,
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-10-28T20:41:17Z',
#   'updated_at': '2021-10-29T22:08:04Z',
#   'associated_tickets_count': 2,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': False,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168193,
#   'priority': 2,
#   'requester_id': 66020186877,
#   'responder_id': 66020186877,
#   'source': 3,
#   'company_id': None,
#   'status': 5,
#   'subject': 'app version showing on SDK search filter',
#   'association_type': 4,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1483,
#   'type': 'Bug',
#   'due_by': '2021-11-17T19:06:59Z',
#   'fr_due_by': '2021-10-29T03:06:59Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': 'aw8oK',
#    'cf_main_cs_contact': 'Harry Schaffer',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-10-28T18:46:58Z',
#   'updated_at': '2021-10-28T23:30:20Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000433581,
#   'priority': 2,
#   'requester_id': 66020321093,
#   'responder_id': 66015092047,
#   'source': 3,
#   'company_id': 66000474227,
#   'status': 5,
#   'subject': 'Android Prod - Westwing is not seeing first party calls on SDK 4.11.3',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1482,
#   'type': 'Bug',
#   'due_by': '2021-11-17T16:17:43Z',
#   'fr_due_by': '2021-10-29T00:17:45Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Prospect',
#    'cf_app_id': '7Reb6',
#    'cf_main_cs_contact': 'Collin Anderson',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-10-28T16:17:45Z',
#   'updated_at': '2021-11-03T15:38:26Z',
#   'associated_tickets_count': None,
#   'tags': ['PRIORITY-ENG-ANDROID'],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': ['mladen@happiestbaby.com', 'support@embrace.io'],
#   'fwd_emails': [],
#   'reply_cc_emails': ['mladen@happiestbaby.com', 'support@embrace.io'],
#   'ticket_cc_emails': [],
#   'fr_escalated': False,
#   'spam': False,
#   'email_config_id': 66000070707,
#   'group_id': 66000168193,
#   'priority': 1,
#   'requester_id': 66019506034,
#   'responder_id': 66004145045,
#   'source': 1,
#   'company_id': 66000390530,
#   'status': 2,
#   'subject': 'Adding a new Admin user',
#   'association_type': None,
#   'support_email': 'embraceiosupport@embraceio.freshdesk.com',
#   'to_emails': ['"support@embrace.io" <support@embrace.io>'],
#   'product_id': None,
#   'id': 1481,
#   'type': None,
#   'due_by': '2021-11-27T12:12:54Z',
#   'fr_due_by': '2021-10-29T12:12:54Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': None,
#    'cf_app_id': None,
#    'cf_main_cs_contact': None,
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-10-28T12:12:54Z',
#   'updated_at': '2021-10-28T17:33:59Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168199,
#   'priority': 3,
#   'requester_id': 66004132337,
#   'responder_id': 66014842864,
#   'source': 3,
#   'company_id': None,
#   'status': 5,
#   'subject': 'Textnow - on hour of data in Snowflake',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1480,
#   'type': None,
#   'due_by': '2021-11-06T21:23:56Z',
#   'fr_due_by': '2021-10-28T01:23:56Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': '53VwF',
#    'cf_main_cs_contact': 'Christine Hermawan',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-10-27T21:23:56Z',
#   'updated_at': '2021-10-30T19:20:55Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000427634,
#   'priority': 3,
#   'requester_id': 66019208299,
#   'responder_id': 66016436026,
#   'source': 100,
#   'company_id': 66000459063,
#   'status': 5,
#   'subject': 'iOS Prod - Embrace is HotelTonights top crash',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1479,
#   'type': 'Bug',
#   'due_by': '2021-11-06T21:04:34Z',
#   'fr_due_by': '2021-10-28T01:04:34Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Prospect',
#    'cf_app_id': 'aZ6uh',
#    'cf_main_cs_contact': 'Collin Anderson',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-10-27T21:04:34Z',
#   'updated_at': '2021-11-01T16:05:08Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168193,
#   'priority': 3,
#   'requester_id': 66019029448,
#   'responder_id': 66004145045,
#   'source': 100,
#   'company_id': 66000361277,
#   'status': 6,
#   'subject': 'Textnow iOS -- on xcode 13 index out of bounds crashes do not appear in Embrace',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1478,
#   'type': 'Bug',
#   'due_by': '2021-11-06T20:18:50Z',
#   'fr_due_by': '2021-10-28T00:18:51Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': '53VwF',
#    'cf_main_cs_contact': 'David Stahl',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-10-27T20:18:51Z',
#   'updated_at': '2021-11-04T22:49:11Z',
#   'associated_tickets_count': None,
#   'tags': ['PRIORITY-ENG-IOS'],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000168193,
#   'priority': 2,
#   'requester_id': 66017283699,
#   'responder_id': 66018795934,
#   'source': 100,
#   'company_id': 66000361269,
#   'status': 10,
#   'subject': 'Crash-Free User Percent dashboard widget bug',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1477,
#   'type': 'Bug',
#   'due_by': '2021-11-15T16:49:20Z',
#   'fr_due_by': '2021-10-27T00:49:20Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Customer',
#    'cf_app_id': 'Z4nGy',
#    'cf_main_cs_contact': 'Brian Schell',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-10-26T16:49:20Z',
#   'updated_at': '2021-10-28T14:14:22Z',
#   'associated_tickets_count': None,
#   'tags': ['PRIORITY-ENG-DASH'],
#   'internal_agent_id': None,
#   'internal_group_id': 66000168199,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': False,
#   'spam': False,
#   'email_config_id': 66000070707,
#   'group_id': 66000168193,
#   'priority': 1,
#   'requester_id': 66021487782,
#   'responder_id': None,
#   'source': 1,
#   'company_id': None,
#   'status': 5,
#   'subject': 'Content Marketing Tactic for both B2B and B2C Businesses.',
#   'association_type': None,
#   'support_email': 'embraceiosupport@embraceio.freshdesk.com',
#   'to_emails': ['"support@embrace.io" <support@embrace.io>'],
#   'product_id': None,
#   'id': 1476,
#   'type': None,
#   'due_by': '2021-11-24T10:18:29Z',
#   'fr_due_by': '2021-10-26T10:18:29Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Other',
#    'cf_app_id': None,
#    'cf_main_cs_contact': None,
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-10-25T10:18:29Z',
#   'updated_at': '2021-10-25T16:06:00Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': ['truenorth@embrace.io',
#    'david.heskett@embrace.io',
#    'victoria@embrace.io',
#    'fredric@embrace.io',
#    'john@embrace.io'],
#   'fwd_emails': [],
#   'reply_cc_emails': ['truenorth@embrace.io',
#    'david.heskett@embrace.io',
#    'victoria@embrace.io',
#    'fredric@embrace.io',
#    'john@embrace.io'],
#   'ticket_cc_emails': [],
#   'fr_escalated': False,
#   'spam': False,
#   'email_config_id': 66000070707,
#   'group_id': 66000168193,
#   'priority': 1,
#   'requester_id': 66021487614,
#   'responder_id': None,
#   'source': 1,
#   'company_id': None,
#   'status': 5,
#   'subject': 'Offering article promotion',
#   'association_type': None,
#   'support_email': 'embraceiosupport@embraceio.freshdesk.com',
#   'to_emails': ['support@embrace.io',
#    'truenorth@embrace.io',
#    'david.heskett@embrace.io',
#    'victoria@embrace.io',
#    'fredric@embrace.io',
#    'john@embrace.io'],
#   'product_id': None,
#   'id': 1475,
#   'type': None,
#   'due_by': '2021-11-24T10:06:38Z',
#   'fr_due_by': '2021-10-26T10:06:38Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Other',
#    'cf_app_id': None,
#    'cf_main_cs_contact': None,
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-10-25T10:06:38Z',
#   'updated_at': '2021-10-25T16:05:43Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000427634,
#   'priority': 3,
#   'requester_id': 66021457389,
#   'responder_id': 66018343495,
#   'source': 3,
#   'company_id': 66000450125,
#   'status': 7,
#   'subject': 'Whaleapp: could not find method swazzler()',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1474,
#   'type': 'Integration',
#   'due_by': '2021-11-02T17:34:19Z',
#   'fr_due_by': '2021-10-23T21:34:19Z',
#   'is_escalated': True,
#   'custom_fields': {'cf_account_type': 'Prospect',
#    'cf_app_id': None,
#    'cf_main_cs_contact': 'Ed Chen',
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-10-23T17:34:19Z',
#   'updated_at': '2021-11-04T18:58:07Z',
#   'associated_tickets_count': None,
#   'tags': ['PRIORITY-ENG-ANDROID'],
#   'internal_agent_id': 66015092047,
#   'internal_group_id': 66000433581,
#   'nr_due_by': None,
#   'nr_escalated': False},
#  {'cc_emails': [],
#   'fwd_emails': [],
#   'reply_cc_emails': [],
#   'ticket_cc_emails': [],
#   'fr_escalated': True,
#   'spam': False,
#   'email_config_id': None,
#   'group_id': 66000433581,
#   'priority': 1,
#   'requester_id': 66018343495,
#   'responder_id': 66020402059,
#   'source': 3,
#   'company_id': None,
#   'status': 2,
#   'subject': 'unity IDE crash using Embrace tool',
#   'association_type': None,
#   'support_email': None,
#   'to_emails': None,
#   'product_id': None,
#   'id': 1473,
#   'type': None,
#   'due_by': '2021-11-22T14:56:14Z',
#   'fr_due_by': '2021-10-24T14:56:14Z',
#   'is_escalated': False,
#   'custom_fields': {'cf_account_type': 'Other',
#    'cf_app_id': None,
#    'cf_main_cs_contact': None,
#    'cf_in_notion_priority_ticket_db': None},
#   'created_at': '2021-10-23T14:56:14Z',
#   'updated_at': '2021-11-04T21:24:52Z',
#   'associated_tickets_count': None,
#   'tags': [],
#   'internal_agent_id': None,
#   'internal_group_id': None,
#   'nr_due_by': None,
#   'nr_escalated': False}]
